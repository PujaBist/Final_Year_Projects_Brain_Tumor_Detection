# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection
# Out:
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 451 bytes | 0 bytes/s, done.
# From https://github.com/PujaBist/Final_Year_Projects_Brain_Tumor_Detection
#  * branch            main       -> FETCH_HEAD
#    16dc742..963fce5  main       -> origin/main
# Updating 16dc742..963fce5
# Fast-forward
#  src/data_split.py | 8 ++++----
#  1 file changed, 4 insertions(+), 4 deletions(-)

# %%
import src.data_split

print(src.data_split.__file__)
# Out:
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/data_split.py

# %%
import sys

# Remove cached module
if "src.data_split" in sys.modules:
    del sys.modules["src.data_split"]

import src.data_split

print(src.data_split.__file__)
print
# Out:
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/data_split.py
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import sys
import importlib
import inspect

print("="*70)
print("STEP 1: Remove cached module")
print("="*70)

if "src.data_split" in sys.modules:
    del sys.modules["src.data_split"]
    print("✅ Removed src.data_split from cache")
else:
    print("ℹ️ src.data_split was not cached")

print("\n" + "="*70)
print("STEP 2: Import again")
print("="*70)

import src.data_split
importlib.reload(src.data_split)

print("Loaded from:")
print(src.data_split.__file__)

print("\n" + "="*70)
print("STEP 3: Current FOLDER_NAME_MAP")
print("="*70)

print(src.data_split.FOLDER_NAME_MAP)

print("\nKeys:")
print(list(src.data_split.FOLDER_NAME_MAP.keys()))

print("\nContains 'notumor'?")
print("notumor" in src.data_split.FOLDER_NAME_MAP)

print("\nContains 'no_tumor'?")
print("no_tumor" in src.data_split.FOLDER_NAME_MAP)

print("\n" + "="*70)
print("STEP 4: Source code around FOLDER_NAME_MAP")
print("="*70)

source = inspect.getsource(src.data_split)
start = source.find("FOLDER_NAME_MAP")
print(source[start:start+400])
# Out:
# ...
# STEP 1: Remove cached module
# ...
# ✅ Removed src.data_split from cache
#
# ...
# STEP 2: Import again
# ...
# Loaded from:
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/data_split.py
#
# ...
# STEP 3: Current FOLDER_NAME_MAP
# ...
# {'glioma': ['glioma', 'Glioma'], 'meningioma': ['meningioma', 'Meningioma'], 'notumor': ['notumor', 'no_tumor', 'No Tumor', 'noTumor'], 'pituitary': ['pituitary', 'Pituitary']}
#
# Keys:
# ['glioma', 'meningioma', 'notumor', 'pituitary']
#
# Contains 'notumor'?
# True
#
# Contains 'no_tumor'?
# False
#
# ...
# STEP 4: Source code around FOLDER_NAME_MAP
# ...
# FOLDER_NAME_MAP = {
#     'glioma': ['glioma', 'Glioma'],
#     'meningioma': ['meningioma', 'Meningioma'],
#     'notumor': ['notumor', 'no_tumor', 'No Tumor', 'noTumor'],
#     'pituitary': ['pituitary', 'Pituitary'],
# }
#
#
# # ─────────────────────────────────────────────────────────────
# # 1. COLLECT ALL IMAGE PATHS FROM MASOUDNICKPARVAR
# # ─────────────────────────────────────────────────────────────
#
# ...

# %%
from src.data_split import create_data_split

split = create_data_split(force_recreate=True)
# Out:
# ...
#   CREATING DATA SPLIT — Masoudnickparvar
#   Ratio : 70 / 15 / 15  (train/val/test)
#   Seed  : 42
# ...
#
# 📁 Loading Masoudnickparvar dataset
#    Path     : /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets
#    Merging Training/ + Testing/ ...
#
#   ✅ Training     →  5600 images
#   ✅ Testing      →  1600 images
#
#   Class             Images
#   ─────────────────────────
#   glioma             1,800
#   meningioma         1,800
#   notumor            1,800
#   pituitary          1,800
#   ─────────────────────────
#   TOTAL              7,200
#
# ✅ Split saved → /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/results/data_split.json
#
# ...
#   DATA SPLIT — Masoudnickparvar  (seed=42)
# ...
#   Subset     Total     glioma    menin   notumor   pituit
#   ───────────────────────────────────────────────────────────
#   TRAIN       5040     1260     1260     1260     1260
#   VAL         1080      270      270      270      270
# ...

# %%
# !ls /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection

print("\n----------------------------")

# !ls /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets

print("\n----------------------------")

# !ls /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Training

print("\n----------------------------")

# !ls /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Testing
# Out:
# Datasets  README.md  requirements_colab.txt  requirements.txt  results	src
#
# ----------------------------
# Testing  Training
#
# ----------------------------
# glioma	meningioma  notumor  pituitary
#
# ----------------------------
# glioma	meningioma  notumor  pituitary

# %%
from src.data_split import create_data_split
split = create_data_split()
# Out:
# ✅ Existing split found — loading:
#    /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/results/data_split.json
#
#
# ...
#   DATA SPLIT — Masoudnickparvar  (seed=42)
# ...
#   Subset     Total     glioma    menin   notumor   pituit
#   ───────────────────────────────────────────────────────────
#   TRAIN       5040     1260     1260     1260     1260
#   VAL         1080      270      270      270      270
#   TEST        1080      270      270      270      270
#   ───────────────────────────────────────────────────────────
#   TOTAL       7200
#
#   Ratio : 70.0% / 15.0% / 15.0%  (target 70/15/15)
# ...

# %%
# !grep "DATASET_DIR" /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/config.py
# Out:
# DATASET_DIR = BASE_DIR / "Datasets"
# TRAIN_DATA_DIR = DATASET_DIR / "Training"
# TEST_DATA_DIR = DATASET_DIR / "Testing"

# %%
import src.config as config

print(config.__file__)

print(dir(config))
# Out:
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/config.py
# ...

# %%
import src.config as config

print(config.TRAIN_DATA_DIR)
print(config.TEST_DATA_DIR)
# Out:
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Training
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Testing

# %%
# !grep -n "DATASET_DIR" src/config.py
# Out:
# 62:DATASET_DIR = BASE_DIR / "Datasets"
# 64:TRAIN_DATA_DIR = DATASET_DIR / "Training"
# 65:TEST_DATA_DIR = DATASET_DIR / "Testing"

# %%
# !grep -n "TRAIN_DATA_DIR" src/config.py
# Out:
# 64:TRAIN_DATA_DIR = DATASET_DIR / "Training"
# 67:# TRAIN_DATA_DIR = Path('/content/drive/MyDrive/Brain_Tumor_Project/data/masoudnickparvar')

# %%
import importlib
import src.config as config

config = importlib.reload(config)

print("Module:", config.__file__)
print("Has DATASET_DIR?", hasattr(config, "DATASET_DIR"))

if hasattr(config, "DATASET_DIR"):
    print("DATASET_DIR:", config.DATASET_DIR)

print("TRAIN_DATA_DIR:", config.TRAIN_DATA_DIR)
print("TEST_DATA_DIR:", config.TEST_DATA_DIR)
# Out:
# Module: /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/config.py
# Has DATASET_DIR? True
# DATASET_DIR: /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets
# TRAIN_DATA_DIR: /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Training
# TEST_DATA_DIR: /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Testing

# %%
split = create_data_split()
# Out:
# ...
#   CREATING DATA SPLIT
#   Ratio  : 70 / 15 / 15  (train/val/test)
#   Seed   : 42
# ...
#
# 📁 Dataset root  : /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/Datasets/Training
#    Subfolders     : ['Training', 'Testing']
#    Merging all images...
#
#   ⚠️  Training/ not found — skipping
#   ⚠️  Testing/ not found — skipping
#
#   Class             Images
#   ─────────────────────────
#   glioma                 0
#   meningioma             0
#   notumor                0
#   pituitary              0
#   ─────────────────────────
#   TOTAL                  0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_757/2862222661.py in <cell line: 0>()
# ----> 1 split = create_data_split()
#
# /content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection/src/data_split.py in create_data_split(force_recreate)
#     185
#     186     if len(all_paths) == 0:
# ...

# %%
import torchvision.transforms as T
from src.data_loader import BrainTumorDataset, create_dataloaders

dummy_transform = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor(),
])

transforms = {
    'train': dummy_transform,
    'val'  : dummy_transform,
    'test' : dummy_transform,
}

dataloaders, datasets = create_dataloaders(split, transforms)
# Out:
# ...
#   DATALOADERS READY
# ...
#   Subset     Images   Batches
#   ────────────────────────────
#   train        5040       157
#   val          1080        34
#   test         1080        34
#   ────────────────────────────
#   TOTAL        7200
# ...

# %%
images, labels = next(iter(dataloaders['train']))

print(f"Batch shape  : {images.shape}")
print(f"Label sample : {labels[:8].tolist()}")
print(f"Pixel range  : [{images.min():.3f}, {images.max():.3f}]")
print("\n✅ Pipeline working!")
# Out:
# Batch shape  : torch.Size([32, 3, 224, 224])
# Label sample : [1, 2, 3, 3, 2, 0, 1, 2]
# Pixel range  : [0.000, 1.000]
#
# ✅ Pipeline working!

# %%
import sys
sys.path.append('/content/drive/MyDrive/Final_Year_Projects_Brain_Tumor_Detection')

from src.utils import set_seed, create_directories
set_seed()
create_directories()
# Out:
# ✅ Seed set to 42 — results are reproducible
# ✅ All result directories ready
